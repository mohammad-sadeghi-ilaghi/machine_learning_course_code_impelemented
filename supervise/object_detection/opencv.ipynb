# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("donkey.jpg")

# %%
plt.axis("off")
plt.imshow(img)

# %%
new_img =cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(new_img)
